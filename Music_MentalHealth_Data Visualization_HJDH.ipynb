# %% [markdown]
# 음악의 중요성은 인류 역사에서 30,000년 이상에 걸쳐 있습니다. 음악과 정신 건강 사이의 연관성은 웰빙에 미치는 깊은 영향으로 인해 광범위하게 논의되고 있습니다.
#
# 음악 치료(MT)는 스트레스 감소, 기분 개선 및 정신적 웰빙을 증진하기 위해 음악을 활용합니다. 이는 근거 기반의 접근법으로, 옥시토신과 같은 "행복" 호르몬을 촉진합니다.
# 연구에 따르면 음악 치료는 우울증, 외상, 정신분열증과 같은 정신 건강 문제에 유익한 효과가 있습니다. 음악은 감정 처리를 돕고, 불안 및 정서 조절 장애를 위한 진정 도구로 작용합니다.
# 데이터 세트에 대한 정보:
#
# 이 데이터 세트는 Kaggle에서 가져온 것입니다.
# 음악 취향과 자기 보고된 정신 건강에 대한 설문 결과입니다.
#
# 데이터분석:
#
# 이 데이터 세트는 개인의 음악 취향과 자기 보고된 정신 건강 상태 사이의 잠재적인 상관관계를 밝혀내는 것을 목표로 합니다. 특정 음악 장르가 정신적 웰빙에 영향을 미치는지 확인하는 것이 목표입니다. 이러한 발견은 음악이 정신 건강과 어떻게 상호작용하는지를 더 잘 이해할 수 있게 하여, 음악 치료(MT)의 보다 정보에 기반한 적용이나 인간 정신의 복잡성에 대한 흥미로운 통찰을 제공할 수 있습니다.

# %% [markdown]
# Attribute Datasets:¶
# 1. Timestamp : Date and time when form was submitted
# 2. Age : Respondent's age
# 3. Primary streaming service : Respondent's primary streaming service
# 4. Hours per day : Number of hours the respondent listens to music per day while working
# 5. While working : Does the respondent listen to music while studying/working?
# 6. Instrumentalist: Does the respondent play an instrument regularly?
# 7. Composer : Does the respondent compose music?
# 8. Fav genre : Respondent's favorite or top genre
# 9. Exploratory : Does the respondent actively explore new artists/genres?
# 10. Foreign languages : Does the respondent regularly listen to music with lyrics in a language they are not fluent in?
# 11. BPM : Beats per minute of favorite genre
# 12. Frequency [Classical] : How frequently the respondent listens to classical music
# 13. Frequency [Country] : How frequently the respondent listens to country music
# 14. Frequency [EDM] : How frequently the respondent listens to EDM music
# 15. Frequency [Folk] : How frequently the respondent listens to folks music
# 16. Frequency [Gospel] : How frequently the respondent listens to Gospel music
# 17. Frequency [Hip hop] : How frequently the respondent listens to hip hop music
# 18. Frequency [Jazz] : How frequently the respondent listens to jazz music
# 19. Frequency [K pop] : How frequently the respondent listens to K pop music
# 20. Frequency [Latin] : How frequently the respondent listens to Latin music
# 21. Frequency [Lofi] : How frequently the respondent listens to lofi music
# 22. Frequency [Metal] : How frequently the respondent listens to metal music
# 23. Frequency [Pop] : How frequently the respondent listens to pop music
# 24. Frequency [R&B] : How frequently the respondent listens to R&B music
# 25. Frequency [Rap] : How frequently the respondent listens to rap music
# 26. Frequency [Rock] : How frequently the respondent listens to rock music
# 27. Frequency [Video game music] : How frequently the respondent listens to video game music
# 28. Anxiety : Self-reported anxiety, on a scale of 0-10
# 29. Depression : Self-reported depression, on a scale of 0-10
# 30. Insomnia : Self-reported insomnia, on a scale of 0-10
# 31. OCD : Self-reported OCD, on a scale of 0-10
# 32. Music effects : Does music improve/worsen respondent's mental health conditions?
# 33. Permissions : Permissions to publicize data

# %% [markdown]
# Import necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


import warnings

warnings.filterwarnings("ignore")
#sns.set(palette="magma")
sns.set(color_codes = True)   
sns.set_palette(palette = 'magma', n_colors = 8)

# %% [markdown]
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
color1 = sns.color_palette("magma",3)
color2 = sns.color_palette("magma")

# %%
df = pd.read_csv('mxmh_survey_results.csv')

# %%
df.head()
# Out:
#             Timestamp   Age Primary streaming service  Hours per day  \
# 0  8/27/2022 19:29:02  18.0                   Spotify            3.0
# 1  8/27/2022 19:57:31  63.0                   Pandora            1.5
# 2  8/27/2022 21:28:18  18.0                   Spotify            4.0
# 3  8/27/2022 21:40:40  61.0             YouTube Music            2.5
# 4  8/27/2022 21:54:47  18.0                   Spotify            4.0
#
#   While working Instrumentalist Composer         Fav genre Exploratory  \
# 0           Yes             Yes      Yes             Latin         Yes
# 1           Yes              No       No              Rock         Yes
# 2            No              No       No  Video game music          No
# 3           Yes              No      Yes              Jazz         Yes
# 4           Yes              No       No               R&B         Yes
#
#   Foreign languages  ...  Frequency [R&B]  Frequency [Rap] Frequency [Rock]  \
# ...

# %%
# data set size check
df.shape
# Out:
# (736, 33)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# check unique values as per dataset
for i in df.columns : 
    print(i)
    print(df[i].unique())
# Out:
# Timestamp
# ['8/27/2022 19:29:02' '8/27/2022 19:57:31' '8/27/2022 21:28:18'
#  '8/27/2022 21:40:40' '8/27/2022 21:54:47' '8/27/2022 21:56:50'
#  '8/27/2022 22:00:29' '8/27/2022 22:18:59' '8/27/2022 22:33:05'
#  '8/27/2022 22:44:03' '8/27/2022 22:51:15' '8/27/2022 23:00:32'
#  '8/27/2022 23:04:00' '8/27/2022 23:12:03' '8/27/2022 23:16:06'
#  '8/27/2022 23:19:52' '8/27/2022 23:39:41' '8/27/2022 23:39:49'
#  '8/27/2022 23:40:55' '8/27/2022 23:41:36' '8/27/2022 23:43:06'
#  '8/28/2022 0:28:02' '8/28/2022 1:39:02' '8/28/2022 3:19:08'
#  '8/28/2022 4:13:11' '8/28/2022 4:38:14' '8/28/2022 4:40:36'
#  '8/28/2022 5:05:51' '8/28/2022 5:16:30' '8/28/2022 8:36:27'
#  '8/28/2022 10:30:22' '8/28/2022 10:38:05' '8/28/2022 10:54:30'
#  '8/28/2022 10:59:53' '8/28/2022 11:08:51' '8/28/2022 11:13:25'
#  '8/28/2022 11:25:49' '8/28/2022 11:27:15' '8/28/2022 11:36:35'
#  '8/28/2022 11:39:21' '8/28/2022 11:50:31' '8/28/2022 11:54:45'
#  '8/28/2022 11:55:54' '8/28/2022 11:58:48' '8/28/2022 12:08:29'
# ...

# %%
# check null values
df.isna().sum()
# Out:
# Timestamp                         0
# Age                               1
# Primary streaming service         1
# Hours per day                     0
# While working                     3
# Instrumentalist                   4
# Composer                          1
# Fav genre                         0
# Exploratory                       0
# Foreign languages                 4
# BPM                             107
# Frequency [Classical]             0
# Frequency [Country]               0
# Frequency [EDM]                   0
# Frequency [Folk]                  0
# Frequency [Gospel]                0
# Frequency [Hip hop]               0
# Frequency [Jazz]                  0
# Frequency [K pop]                 0
# Frequency [Latin]                 0
# Frequency [Lofi]                  0
# Frequency [Metal]                 0
# Frequency [Pop]                   0
# Frequency [R&B]                   0
# Frequency [Rap]                   0
# Frequency [Rock]                  0
# ...

# %% [markdown]
# Missing values:¶
# To handle missing values: delete if insignificant, impute with mean/median/mode, regression, or KNN; use forward/backward-fill for time-series, interpolate, apply domain knowledge, or create indicator variable. Choose based on data and analysis goals.

# %%
df["Age"] = df["Age"].fillna(df["Age"].median())
df["Primary streaming service"] = df["Primary streaming service"].fillna(df["Primary streaming service"].mode()[0])
df["While working"] = df["While working"].fillna(df["While working"].mode()[0])
df["Instrumentalist"] = df["Instrumentalist"].fillna(df["Instrumentalist"].mode()[0])
df["Composer"] = df["Composer"].fillna(df["Composer"].mode()[0])
df["Foreign languages"] = df["Foreign languages"].fillna(df["Foreign languages"].mode()[0])
#df["BPM"] = df["BPM"].fillna(df["BPM"].median())
df["Music effects"] = df["Music effects"].fillna(df["Music effects"].mode()[0])

# %%
df.isna().sum()
# Out:
# Timestamp                         0
# Age                               0
# Primary streaming service         0
# Hours per day                     0
# While working                     0
# Instrumentalist                   0
# Composer                          0
# Fav genre                         0
# Exploratory                       0
# Foreign languages                 0
# BPM                             107
# Frequency [Classical]             0
# Frequency [Country]               0
# Frequency [EDM]                   0
# Frequency [Folk]                  0
# Frequency [Gospel]                0
# Frequency [Hip hop]               0
# Frequency [Jazz]                  0
# Frequency [K pop]                 0
# Frequency [Latin]                 0
# Frequency [Lofi]                  0
# Frequency [Metal]                 0
# Frequency [Pop]                   0
# Frequency [R&B]                   0
# Frequency [Rap]                   0
# Frequency [Rock]                  0
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                Timestamp   Age Primary streaming service  Hours per day  \
# 0     8/27/2022 19:29:02  18.0                   Spotify            3.0
# 1     8/27/2022 19:57:31  63.0                   Pandora            1.5
# 2     8/27/2022 21:28:18  18.0                   Spotify            4.0
# 3     8/27/2022 21:40:40  61.0             YouTube Music            2.5
# 4     8/27/2022 21:54:47  18.0                   Spotify            4.0
# ..                   ...   ...                       ...            ...
# 731  10/30/2022 14:37:28  17.0                   Spotify            2.0
# 732   11/1/2022 22:26:42  18.0                   Spotify            1.0
# 733   11/3/2022 23:24:38  19.0   Other streaming service            6.0
# 734   11/4/2022 17:31:47  19.0                   Spotify            5.0
# 735    11/9/2022 1:55:20  29.0             YouTube Music            2.0
#
# ...

# %%
# change datatypes paricaler column
df["Age"] = df["Age"].astype(int)

# %%
df.head(2)
# Out:
#             Timestamp  Age Primary streaming service  Hours per day  \
# 0  8/27/2022 19:29:02   18                   Spotify            3.0
# 1  8/27/2022 19:57:31   63                   Pandora            1.5
#
#   While working Instrumentalist Composer Fav genre Exploratory  \
# 0           Yes             Yes      Yes     Latin         Yes
# 1           Yes              No       No      Rock         Yes
#
#   Foreign languages  ...  Frequency [R&B]  Frequency [Rap] Frequency [Rock]  \
# 0               Yes  ...        Sometimes  Very frequently            Never
# 1                No  ...        Sometimes           Rarely  Very frequently
#
#   Frequency [Video game music] Anxiety Depression Insomnia  OCD Music effects  \
# 0                    Sometimes     3.0        0.0      1.0  0.0       Improve
# 1                       Rarely     7.0        2.0      2.0  1.0       Improve
#
#      Permissions
# 0  I understand.
# 1  I understand.
#
# [2 rows x 33 columns]

# %% [markdown]
# Describe:
# Handling missing values: addressing empty data slots by deleting, imputing with estimations, or using domain knowledge for accuracy.

# %%
df.describe().T
# Out:
#                count          mean           std   min    25%    50%    75%  \
# Age            736.0  2.520109e+01  1.204776e+01  10.0   18.0   21.0   28.0
# Hours per day  736.0  3.572758e+00  3.028199e+00   0.0    2.0    3.0    5.0
# BPM            629.0  1.589948e+06  3.987261e+07   0.0  100.0  120.0  144.0
# Anxiety        736.0  5.837636e+00  2.793054e+00   0.0    4.0    6.0    8.0
# Depression     736.0  4.796196e+00  3.028870e+00   0.0    2.0    5.0    7.0
# Insomnia       736.0  3.738451e+00  3.088689e+00   0.0    1.0    3.0    6.0
# OCD            736.0  2.637228e+00  2.842017e+00   0.0    0.0    2.0    5.0
#
#                        max
# Age                   89.0
# Hours per day         24.0
# BPM            999999999.0
# Anxiety               10.0
# Depression            10.0
# Insomnia              10.0
# OCD                   10.0

# %%
df.describe(include="object").T
# Out:
#                              count unique                 top freq
# Timestamp                      736    735  8/28/2022 16:15:08    2
# Primary streaming service      736      6             Spotify  459
# While working                  736      2                 Yes  582
# Instrumentalist                736      2                  No  501
# Composer                       736      2                  No  610
# Fav genre                      736     16                Rock  188
# Exploratory                    736      2                 Yes  525
# Foreign languages              736      2                 Yes  408
# Frequency [Classical]          736      4              Rarely  259
# Frequency [Country]            736      4               Never  343
# Frequency [EDM]                736      4               Never  307
# Frequency [Folk]               736      4               Never  292
# Frequency [Gospel]             736      4               Never  535
# ...

# %% [markdown]
# Remove outliers

# %%
age_index = df[(df['Age'] > 70)].index
df = df.drop(age_index, axis=0)

# %%
bpm_index = df[df['BPM'] > 200].index
df = df.drop(bpm_index, axis=0)

# %%
hpd_index = df[df['Hours per day'] >= 15].index
df = df.drop(hpd_index, axis=0)

# %%
miss_bpm_genre = ['Country', 'Hip hop', 'Pop', 'Rock', 'Metal', 'Classical',
       'Video game music', 'R&B', 'Folk', 'Jazz', 'EDM', 'Gospel',
       'K pop', 'Rap']

# %%
for i in miss_bpm_genre:
  df['BPM'] = df['BPM'].fillna(round(df[df['Fav genre']== i ]['BPM'].mode(), 0))
df['BPM']
# Out:
# 0      156.0
# 1      119.0
# 2      132.0
# 3       84.0
# 4      107.0
#        ...
# 731    120.0
# 732    160.0
# 733    120.0
# 734    170.0
# 735     98.0
# Name: BPM, Length: 714, dtype: float64

# %%
df.head(2)
# Out:
#             Timestamp  Age Primary streaming service  Hours per day  \
# 0  8/27/2022 19:29:02   18                   Spotify            3.0
# 1  8/27/2022 19:57:31   63                   Pandora            1.5
#
#   While working Instrumentalist Composer Fav genre Exploratory  \
# 0           Yes             Yes      Yes     Latin         Yes
# 1           Yes              No       No      Rock         Yes
#
#   Foreign languages  ...  Frequency [R&B]  Frequency [Rap] Frequency [Rock]  \
# 0               Yes  ...        Sometimes  Very frequently            Never
# 1                No  ...        Sometimes           Rarely  Very frequently
#
#   Frequency [Video game music] Anxiety Depression Insomnia  OCD Music effects  \
# 0                    Sometimes     3.0        0.0      1.0  0.0       Improve
# 1                       Rarely     7.0        2.0      2.0  1.0       Improve
#
#      Permissions
# 0  I understand.
# 1  I understand.
#
# [2 rows x 33 columns]

# %% [markdown]
# Data Visualization

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=df,x="Primary streaming service",palette=color2)
# Out:
# <Axes: xlabel='Primary streaming service', ylabel='count'>

# %% [markdown]
# 관찰:
# 1. 대부분의 사람들은 Spotify와 YouTube와 같은 스트리밍 서비스를 사용하는 경향이 있습니다

# %%
plt.figure(figsize=(15,5))
sns.histplot(data=df,x="Age")
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# 관찰:
# 1. 주로 음악 스트리밍과 곡을 즐기는 연령대는 18세에서 27세 사이입니다.

# %%
plt.figure(figsize=(15,5))
sns.histplot(data=df,x="Hours per day")
# Out:
# <Axes: xlabel='Hours per day', ylabel='Count'>

# %% [markdown]
# 관찰:
# 1. 대부분의 사람들은 하루에 1시간에서 4시간 동안 음악을 듣습니다.

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.countplot(data=df,x="While working",palette=color1)
plt.subplot(2,2,2)
plt.pie(df["While working"].value_counts(),colors=color1,labels=["Yes","No"],autopct="%0.1f%%")
plt.show()

# %% [markdown]
# 관찰:
# 1. 대부분의 사람들이 음악을 듣는 주체는 주로 직장인이며, 약 79%에 해당합니다.

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=df,x="Fav genre")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# 관찰:
# 1. 대부분의 사람들은 록, 팝, 메탈 음악을 듣는 경향이 있습니다.

# %%
plt.figure(figsize=(15,5))
sns.histplot(df["BPM"])
# Out:
# <Axes: xlabel='BPM', ylabel='Count'>

# %%
df.columns
# Out:
# Index(['Timestamp', 'Age', 'Primary streaming service', 'Hours per day',
#        'While working', 'Instrumentalist', 'Composer', 'Fav genre',
#        'Exploratory', 'Foreign languages', 'BPM', 'Frequency [Classical]',
#        'Frequency [Country]', 'Frequency [EDM]', 'Frequency [Folk]',
#        'Frequency [Gospel]', 'Frequency [Hip hop]', 'Frequency [Jazz]',
#        'Frequency [K pop]', 'Frequency [Latin]', 'Frequency [Lofi]',
#        'Frequency [Metal]', 'Frequency [Pop]', 'Frequency [R&B]',
#        'Frequency [Rap]', 'Frequency [Rock]', 'Frequency [Video game music]',
#        'Anxiety', 'Depression', 'Insomnia', 'OCD', 'Music effects',
#        'Permissions'],
#       dtype='object')

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.countplot(data=df,x="Frequency [Classical]")
plt.subplot(2,2,2)
sns.countplot(data=df,x="Frequency [Metal]")
plt.show()

# %% [markdown]
# o관찰:
# 1.  대부분의 사람들은 클래식 음악을 드물게 또는 가끔 듣고,
# 2. 메탈 음악은 거의 듣지 않거나 드물게 듣는 경향이 있습니다

# %%
plt.figure(figsize=(15,7))
sns.lineplot(data=df,x="Fav genre",y="Age")
plt.xticks(rotation=67)
plt.show()

# %% [markdown]
# 관찰:
# 지정된 지역에서 모든 종류의 음악을 듣는 20세에서 30세 사이의 개인들의 평균 나이는 약 25세입니다. Lofi 음악을 주로 즐기는 최대 연령대는 30세에서 50세 사이입니다.

# %%
plt.figure(figsize=(15,5))
sns.boxplot(data=df,x="Fav genre",y="Hours per day")
plt.xticks(rotation=67)
plt.show()

# %% [markdown]
# 관찰:
# 해당 지역의 대부분 사람들은 라틴 음악과 재즈 음악을 하루 평균 한 시간씩 듣습니다.

# %%
plt.figure(figsize=(15,5))
sns.barplot(data=df,x="Fav genre",y="Depression",errwidth=0)
plt.xticks(rotation=67)
plt.show()

# %% [markdown]
# 관찰:
# Lofi, 록, 힙합 음악을 듣는 것이 우울증을 직접적으로 나타내는 것은 아닙니다. 정신 건강은 복잡하며, 음악은 여러 요인 중 하나일 뿐입니다. 필요하다면 전문적인 도움을 받는 것이 중요합니다.

# %%
plt.figure(figsize=(15,5))
sns.barplot(data=df,x="Fav genre",y="Anxiety",errwidth=0)
plt.xticks(rotation=67)
plt.show()

# %% [markdown]
# 관찰:
# 불안을 경험하는 많은 개인들이 록, K-pop, 포크와 같은 장르에 끌립니다. 그러나 음악 취향은 다양하며, 오직 정신 건강 문제를 나타내는 것은 아닙니다. 불안을 관리하는 데는 전문적인 지원이 중요합니다.

# %%
plt.figure(figsize=(15,5))
sns.barplot(data=df,x="Fav genre",y="Insomnia",errwidth=0)
plt.xticks(rotation=67)
plt.show()

# %% [markdown]
# 관찰:
# 교회음악과 Lofi 음악을 듣는 많은 사람들이 불면증을 경험할 수 있지만, 음악 선택만으로 불면증이 직접적으로 발생한다고 이해하는 것은 중요합니다. 불면증은 여러 가지 원인이 있으며, 적절한 평가와 치료가 필요합니다.

# %%
plt.figure(figsize=(15,7))
sns.barplot(data=df,x="Fav genre",y="Age",hue="Music effects",errwidth=0,palette="mako_r")
plt.xticks(rotation=67)
plt.show()

# %% [markdown]
# 관찰:
# 모든 연령대의 청취자들은 일반적으로 음악으로부터 어느 정도의 개선을 경험하지만, 록, 비디오 게임 음악, 팝, 랩, 클래식과 같은 장르는 일부 개인에게는 상태를 악화시키는 것으로 보입니다.

# %%
plt.figure(figsize=(15,7))
sns.barplot(data=df,x="Fav genre",y="Hours per day",hue="Music effects",errwidth=0,palette="mako_r")
plt.xticks(rotation=67)
plt.show()

# %% [markdown]
# 관찰:
# 재즈, Lofi, K-pop 음악을 듣는 청취자들은 하루 몇 시간 동안 음악을 즐기면서 기분과 전반적인 웰빙이 개선되는 경향이 있습니다.

# %%
plt.figure(figsize=(15,7))
sns.barplot(data=df,x="Fav genre",y="Anxiety",hue="Music effects",errwidth=0,palette="mako_r")
plt.xticks(rotation=67)
plt.show()

# %% [markdown]
# 관찰:
# 록, 비디오 게임 음악, 팝, 랩, 클래식 장르를 듣는 청취자들은 다양한 수준의 불안을 나타냅니다. 이 중에서 비디오 게임 음악 청취자들이 가장 높은 수준의 불안을 경험하는 경향이 있습니다.

# %%
plt.figure(figsize=(15,7))
sns.barplot(data=df,x="Fav genre",y="Anxiety",hue="Music effects",errwidth=0,palette="mako_r")
plt.xticks(rotation=67)
plt.show()

# %% [markdown]
# 관찰:
# 록, 비디오 게임 음악, 팝, 랩, 클래식 장르를 듣는 청취자들은 다양한 수준의 불안을 나타냅니다. 이 중에서 비디오 게임 음악 청취자들이 가장 높은 수준의 불안을 경험하는 경향이 있습니다.

# %%
plt.figure(figsize=(15,7))
sns.barplot(data=df,x="Fav genre",y="Insomnia",hue="Music effects",errwidth=0,palette="mako_r")
plt.xticks(rotation=67)
plt.show()

# %% [markdown]
# 관찰:
# 록, 비디오 게임 음악, 팝, 클래식 장르를 듣는 청취자들은 불면증을 경험할 경향이 있습니다. 이 중에서 비디오 게임 음악 청취자들이 가장 높은 수준의 불면증을 겪는 경향이 있습니다.

# %% [markdown]
# 결론:
# 정확히 말씀하신 대로입니다. 음악은 정신 건강에 이중적인 영향을 미칠 수 있습니다. 일부 개인에게는 기분과 전반적인 웰빙을 개선하는 긍정적인 효과가 있지만, 다른 사람들에게는 록, 비디오 게임 음악, 팝, 클래식과 같은 특정 장르가 긍정적인 영향을 주지 않거나 정신 건강 상태를 악화시킬 수 있습니다. 음악의 영향은 매우 개인적이며, 개인의 취향, 경험, 기존의 정신 건강 상태 등의 다양한 요인에 따라 달라진다는 것을 인식하는 것이 중요합니다. 정신 건강에 어려움을 겪고 있는 경우, 전문적인 조언과 지원을 받는 것이 권장되지만 음악치료의 확장가능성도 확인할수 있었습니다.
